# %%
# %matplotlib inline
#Standard imports
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ortho_group


#own modules
import myplots
from tensor_util import *
from main_function import f, df, ddf, dddf

g_name = "exp"
def g(x):
    return np.exp(x)
dg=ddg=dddg=g
# Out:
# [myplots.py]: Saving plots to /home/pca/code/ma/plots

# %%
def uniformSphere(d, m_x):
    x = np.random.normal(size=(m_x,d))
    for i in range(m_x):
        x[i] = x[i] / np.linalg.norm(x[i])
    return x

def perm_matrix(m):
    P = np.identity(m)
    P = np.random.permutation(P)#permutes only the rows
    return P, np.linalg.inv(P)
def decomp_svd_dd(X,A,B, randomize=False):
    """tbd.

    Parameters
    ----------
    X : matrix
        m_x samples \in R^m
    A : matrix
        m orthonormal vectors \in R^m
    B : matrix
        m_1 orthonormal vectors \in R^m
    randomize: bool
        if true performs a random unfolding
    Returns
    -------
    alot

    """
    m = A.shape[1]
    ddf_values = ddf(X,A,B)
    unfolds = [np.reshape(dd, (m**2,)) for dd in ddf_values]
    
    if randomize:
        P,Q = perm_matrix(m**2)
        unfolds = [np.dot(P,v) for v in unfolds]
        
    M = np.transpose(np.array(unfolds))
    U,D,V = np.linalg.svd(M)
    if randomize: 
        U = np.dot(Q,U)
    return ddf_values, U, D
        
    
def decomp_svd_ddd(X,A,B, randomize=False):
    """tbd.

    Parameters
    ----------
    X : matrix
        m_x samples \in R^m
    A : matrix
        m orthonormal vectors \in R^m
    B : matrix
        m_1 orthonormal vectors \in R^m
    randomize: bool
        if true performs a random unfolding
    Returns
    -------
    alot

    """
    m = A.shape[1]
    dddf_values = dddf(X,A,B)
    unfolds = [np.reshape(dd, (m**3,)) for dd in dddf_values]
    
    if randomize:
        P,Q = perm_matrix(m**3)
        unfolds = [np.dot(P,v) for v in unfolds]
        
    M = np.transpose(np.array(unfolds))
    U,D,V = np.linalg.svd(M)
    if randomize: 
        U = np.dot(Q,U)
    return dddf_values, U, D

# %%
#Setting parameters, and creating data
m = 4
m_1 = 1
m_x = 1000
X = uniformSphere(m, m_x)
A = ortho_group.rvs(dim = m)# m orthogonal vectors with dim m, a_1, ..., a_m
A = np.transpose(A)
B = ortho_group.rvs(dim = m)[:m_1]#m_1 orthogonal vectors with dimension m b_1, ..., b_m_1
B = np.transpose(B)

# %%
ddf_values, U_dd, D_dd = decomp_svd_dd(X,A,B,randomize=True)
myplots.plot_singular_values(D_dd, m, m_1, m_x, der = 2, filename= g_name + "2nd_4.pdf")
k = m+m_1

print("SVD for unfolding of second derivative:")
ratio_sv_1 = np.sum(D_dd[:k])/np.sum(D_dd)
ratio_sv_2 = np.sum(D_dd[:2*m])/np.sum(D_dd)
print("Ratio singular values: (sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}".format(k, ratio_sv_1))
print("Ratio singular values: (sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}".format(2*m, ratio_sv_2))

print("\nMinimal distance of a_i*a_i to the first m+m_1 left singular vectors:")
for i in range(m):
    print("dist(U[:, :{}], a_{}*a_{}) = {:.6f}".format(k,i,i,np.min(tensor_distance_to_columns(A[:,i], U_dd, k, mode=2))))
print("\nMinimal distance of a_i*a_i to the first 2m left singular vectors:")
for i in range(m):
    print("dist(U[:, :{}], a_{}*a_{}) = {:.6f}".format(2*m,i,i,np.min(tensor_distance_to_columns(A[:,i], U_dd, 2*m, mode=2))))
# Out:
# SVD for unfolding of second derivative:
# Ratio singular values: (sv_1+ ...+ sv_5)/(sum_i sv_i)=0.997826
# Ratio singular values: (sv_1+ ...+ sv_8)/(sum_i sv_i)=0.999969
#
# Minimal distance of a_i*a_i to the first m+m_1 left singular vectors:
# dist(U[:, :5], a_0*a_0) = 0.594633
# dist(U[:, :5], a_1*a_1) = 0.592210
# dist(U[:, :5], a_2*a_2) = 0.062144
# dist(U[:, :5], a_3*a_3) = 0.056474
#
# Minimal distance of a_i*a_i to the first 2m left singular vectors:
# dist(U[:, :8], a_0*a_0) = 0.594633
# dist(U[:, :8], a_1*a_1) = 0.592210
# dist(U[:, :8], a_2*a_2) = 0.062144
# dist(U[:, :8], a_3*a_3) = 0.056474

# %%
dddf_values, U_ddd, D_ddd = decomp_svd_ddd(X,A,B, randomize=False)
myplots.plot_singular_values(D_ddd, m,m_1,m_x, der = 3, filename=g_name + "3rd_4.pdf")
k = m+m_1

print("\nSVD for unfolding of third derivative:")
ratio_sv_1 = np.sum(D_ddd[:k])/np.sum(D_ddd)
ratio_sv_2 = np.sum(D_ddd[:2*m])/np.sum(D_ddd)

print("Ratio singular values:(sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}".format(k, ratio_sv_1))
print("Ratio singular values:(sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}".format(2*m, ratio_sv_2))
print("\nMinimal distance of a_i*a_i*a_i to the first m+m_1 left singular vectors:")
for i in range(m):
    print("dist(U[:, :{}], a_{}*a_{}*a_{}) = {:.6f}".format(k,i,i,i,np.min(tensor_distance_to_columns(A[:,i], U_ddd, k, mode=3))))
print("\nMinimal distance of a_i*a_i*a_i to the first 2m left singular vectors:")
for i in range(m):
    print("dist(U[:, :{}], a_{}*a_{}*a_{}) = {:.6f}".format(2*m,i,i,i,np.min(tensor_distance_to_columns(A[:,i], U_ddd, 2*m, mode=3))))
# Out:
# SVD for unfolding of third derivative:
# Ratio singular values:(sv_1+ ...+ sv_5)/(sum_i sv_i)=0.993056
# Ratio singular values:(sv_1+ ...+ sv_8)/(sum_i sv_i)=0.998924
#
# Minimal distance of a_i*a_i*a_i to the first m+m_1 left singular vectors:
# dist(U[:, :5], a_0*a_0*a_0) = 0.744277
# dist(U[:, :5], a_1*a_1*a_1) = 0.634527
# dist(U[:, :5], a_2*a_2*a_2) = 0.539218
# dist(U[:, :5], a_3*a_3*a_3) = 0.643238
#
# Minimal distance of a_i*a_i*a_i to the first 2m left singular vectors:
# dist(U[:, :8], a_0*a_0*a_0) = 0.744277
# dist(U[:, :8], a_1*a_1*a_1) = 0.634527
# dist(U[:, :8], a_2*a_2*a_2) = 0.539218
# dist(U[:, :8], a_3*a_3*a_3) = 0.643238

# %%
m = [2**k for k in range(1,6)]
m_x = [8**k for k in range(1, 5)]
m_1 = 1
ratio_dd = np.zeros((5,4))
ratio_ddd = np.zeros((5,4))
average_dists_dd = np.zeros((5,4))
average_dists_ddd = np.zeros((5,4))

for i in range(5):
    A = ortho_group.rvs(dim = m[i])
    A = np.transpose(A)
    B = ortho_group.rvs(dim = m[i])[:m_1]
    B = np.transpose(B)
    for j in range(i, 4):
        print("\n*****************************************************")
        print("Running for m={},m_1={}, m_x={}:\n".format(m[i],m_1,m_x[j]))
        X = uniformSphere(m[i], m_x[j])
        print("\nSVD for unfolding of second derivative:")
        ddf_values, U_dd, D_dd = decomp_svd_dd(X,A,B,randomize=True)
        k = m[i]+m_1

        ratio_sv_1 = np.sum(D_dd[:k])/np.sum(D_dd)
        ratio_sv_2 = np.sum(D_dd[:2*m[i]])/np.sum(D_dd)
        #ratio_dd[i,j] = ratio_sv
        print("Ratio sv(m+m_1): (sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}\n".format(k, ratio_sv_1))
        print("Ratio sv(2m): (sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}\n".format(2*m[i], ratio_sv_2))
        
        dists_1 = []
        dists_2 = []
        for ind in range(m[i]):
            d_1 = np.min(tensor_distance_to_columns(A[:,ind], U_dd, k, mode=2))
            dists_1.append(d_1)
            d_2 = np.min(tensor_distance_to_columns(A[:,ind], U_dd, m[i]*2, mode=2))
            dists_2.append(d_2)
        avg_1 = np.mean(dists_1)
        min_1 = np.min(dists_1)
        max_1 = np.max(dists_1)
        avg_2 = np.mean(dists_2)
        min_2 = np.min(dists_2)
        max_2 = np.max(dists_2)
        #average_dists_dd[i,j]=avg
        print("Average dist (m+m_1): {:.6f}".format(avg_1))
        print("Minmal dist (m+m_1): {:.6f}".format(min_1))
        print("Maximal dist (m+m_1): {:.6f}".format(max_1))
        print("Average dist (2m): {:.6f}".format(avg_2))
        print("Minimal dist (2m): {:.6f}".format(min_2))
        print("Maximal dist (2m): {:.6f}".format(max_2))        
        #third derivative
        
        print("\nSVD for unfolding of third derivative:")
        dddf_values, U_ddd, D_ddd = decomp_svd_ddd(X,A,B,randomize=True)
        k = m[i]+m_1
        
        ratio_sv_1 = np.sum(D_ddd[:k])/np.sum(D_ddd)
        ratio_sv_2 = np.sum(D_ddd[:2*m[i]])/np.sum(D_ddd)
        #ratio_ddd[i,j] = ratio_sv
        print("Ratio sv(m+m_1): (sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}\n".format(k, ratio_sv_1))
        print("Ratio sv(2m): (sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}\n".format(2*m[i], ratio_sv_2))
        
        dists_1 = []
        dists_2 = []
        for ind in range(m[i]):
            d_1 = np.min(tensor_distance_to_columns(A[:,ind], U_ddd, k, mode=3))
            dists_1.append(d_1)
            d_2 = np.min(tensor_distance_to_columns(A[:,ind], U_ddd, m[i]*2, mode=3))
            dists_2.append(d_2)
        avg_1 = np.mean(dists_1)
        min_1 = np.min(dists_1)
        max_1 = np.max(dists_1)
        avg_2 = np.mean(dists_2)
        min_2 = np.min(dists_2)
        max_2 = np.max(dists_2)
        #average_dists_dd[i,j]=avg
        print("Average dist (m+m_1): {:.6f}".format(avg_1))
        print("Minmal dist (m+m_1): {:.6f}".format(min_1))
        print("Maximal dist (m+m_1): {:.6f}".format(max_1))
        print("Average dist (2m): {:.6f}".format(avg_2))
        print("Minimal dist (2m): {:.6f}".format(min_2))
        print("Maximal dist (2m): {:.6f}".format(max_2))    
            

        #avg = np.mean(dists)
        #average_dists_ddd[i,j]=avg
# Out:
# *****************************************************
# Running for m=2,m_1=1, m_x=8:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=1.000000
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.055925
# Minmal dist (m+m_1): 0.013743
# Maximal dist (m+m_1): 0.098107
# Average dist (2m): 0.055925
# Minimal dist (2m): 0.013743
# Maximal dist (2m): 0.098107
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=0.965684
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.624054
# Minmal dist (m+m_1): 0.621021
# Maximal dist (m+m_1): 0.627087
# Average dist (2m): 0.624054
# Minimal dist (2m): 0.621021
# Maximal dist (2m): 0.627087
#
# *****************************************************
# Running for m=2,m_1=1, m_x=64:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=1.000000
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.346088
# Minmal dist (m+m_1): 0.344272
# Maximal dist (m+m_1): 0.347904
# Average dist (2m): 0.346088
# Minimal dist (2m): 0.344272
# Maximal dist (2m): 0.347904
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=0.961975
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.656382
# Minmal dist (m+m_1): 0.656325
# Maximal dist (m+m_1): 0.656439
# Average dist (2m): 0.656382
# Minimal dist (2m): 0.656325
# Maximal dist (2m): 0.656439
#
# *****************************************************
# Running for m=2,m_1=1, m_x=512:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=1.000000
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.060581
# Minmal dist (m+m_1): 0.053832
# Maximal dist (m+m_1): 0.067329
# Average dist (2m): 0.060581
# Minimal dist (2m): 0.053832
# Maximal dist (2m): 0.067329
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=0.962541
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.674150
# Minmal dist (m+m_1): 0.673955
# Maximal dist (m+m_1): 0.674345
# Average dist (2m): 0.674150
# Minimal dist (2m): 0.673955
# Maximal dist (2m): 0.674345
#
# *****************************************************
# Running for m=2,m_1=1, m_x=4096:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=1.000000
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.153580
# Minmal dist (m+m_1): 0.152737
# Maximal dist (m+m_1): 0.154423
# Average dist (2m): 0.153580
# Minimal dist (2m): 0.152737
# Maximal dist (2m): 0.154423
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=0.963037
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.672483
# Minmal dist (m+m_1): 0.672268
# Maximal dist (m+m_1): 0.672697
# Average dist (2m): 0.672483
# Minimal dist (2m): 0.672268
# Maximal dist (2m): 0.672697
#
# *****************************************************
# Running for m=4,m_1=1, m_x=64:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_5)/(sum_i sv_i)=0.985545
#
# Ratio sv(2m): (sv_1+ ...+ sv_8)/(sum_i sv_i)=0.999906
#
# Average dist (m+m_1): 0.349196
# Minmal dist (m+m_1): 0.032162
# Maximal dist (m+m_1): 0.537401
# Average dist (2m): 0.349196
# Minimal dist (2m): 0.032162
# Maximal dist (2m): 0.537401
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_5)/(sum_i sv_i)=0.953455
#
# Ratio sv(2m): (sv_1+ ...+ sv_8)/(sum_i sv_i)=0.995903
#
# Average dist (m+m_1): 0.902127
# Minmal dist (m+m_1): 0.711710
# Maximal dist (m+m_1): 1.347895
# Average dist (2m): 0.611646
# Minimal dist (2m): 0.185972
# Maximal dist (2m): 0.785602
#
# *****************************************************
# Running for m=4,m_1=1, m_x=512:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_5)/(sum_i sv_i)=0.986694
#
# Ratio sv(2m): (sv_1+ ...+ sv_8)/(sum_i sv_i)=0.999907
#
# Average dist (m+m_1): 0.196831
# Minmal dist (m+m_1): 0.017395
# Maximal dist (m+m_1): 0.315721
# Average dist (2m): 0.196831
# Minimal dist (2m): 0.017395
# Maximal dist (2m): 0.315721
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_5)/(sum_i sv_i)=0.949667
#
# Ratio sv(2m): (sv_1+ ...+ sv_8)/(sum_i sv_i)=0.995931
#
# Average dist (m+m_1): 0.910361
# Minmal dist (m+m_1): 0.678433
# Maximal dist (m+m_1): 1.357894
# Average dist (2m): 0.604748
# Minimal dist (2m): 0.135441
# Maximal dist (2m): 0.857603
#
# *****************************************************
# Running for m=4,m_1=1, m_x=4096:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_5)/(sum_i sv_i)=0.986113
#
# Ratio sv(2m): (sv_1+ ...+ sv_8)/(sum_i sv_i)=0.999911
#
# Average dist (m+m_1): 0.217548
# Minmal dist (m+m_1): 0.010701
# Maximal dist (m+m_1): 0.327410
# Average dist (2m): 0.217548
# Minimal dist (2m): 0.010701
# Maximal dist (2m): 0.327410
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_5)/(sum_i sv_i)=0.950408
#
# Ratio sv(2m): (sv_1+ ...+ sv_8)/(sum_i sv_i)=0.995987
#
# Average dist (m+m_1): 0.896240
# Minmal dist (m+m_1): 0.628777
# Maximal dist (m+m_1): 1.352419
# Average dist (2m): 0.590185
# Minimal dist (2m): 0.128197
# Maximal dist (2m): 0.869355
#
# *****************************************************
# Running for m=8,m_1=1, m_x=512:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_9)/(sum_i sv_i)=0.991418
#
# Ratio sv(2m): (sv_1+ ...+ sv_16)/(sum_i sv_i)=0.999791
#
# Average dist (m+m_1): 0.268944
# Minmal dist (m+m_1): 0.038829
# Maximal dist (m+m_1): 0.452086
# Average dist (2m): 0.268944
# Minimal dist (2m): 0.038829
# Maximal dist (2m): 0.452086
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_9)/(sum_i sv_i)=0.966511
#
# Ratio sv(2m): (sv_1+ ...+ sv_16)/(sum_i sv_i)=0.996928
#
# Average dist (m+m_1): 0.716273
# Minmal dist (m+m_1): 0.193349
# Maximal dist (m+m_1): 1.371519
# Average dist (2m): 0.623340
# Minimal dist (2m): 0.193349
# Maximal dist (2m): 0.850590
#
# *****************************************************
# Running for m=8,m_1=1, m_x=4096:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_9)/(sum_i sv_i)=0.991322
#
# Ratio sv(2m): (sv_1+ ...+ sv_16)/(sum_i sv_i)=0.999788
#
# Average dist (m+m_1): 0.313150
# Minmal dist (m+m_1): 0.010085
# Maximal dist (m+m_1): 0.663735
# Average dist (2m): 0.313150
# Minimal dist (2m): 0.010085
# Maximal dist (2m): 0.663735
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_9)/(sum_i sv_i)=0.966241
#
# Ratio sv(2m): (sv_1+ ...+ sv_16)/(sum_i sv_i)=0.996874
#
# Average dist (m+m_1): 0.715553
# Minmal dist (m+m_1): 0.174662
# Maximal dist (m+m_1): 1.376538
# Average dist (2m): 0.559076
# Minimal dist (2m): 0.124725
# Maximal dist (2m): 0.879487
#
# *****************************************************
# Running for m=16,m_1=1, m_x=4096:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_17)/(sum_i sv_i)=0.991760
#
# Ratio sv(2m): (sv_1+ ...+ sv_32)/(sum_i sv_i)=0.999790
#
# Average dist (m+m_1): 0.439042
# Minmal dist (m+m_1): 0.011685
# Maximal dist (m+m_1): 0.794977
# Average dist (2m): 0.439042
# Minimal dist (2m): 0.011685
# Maximal dist (2m): 0.794977
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_17)/(sum_i sv_i)=0.958270
#
# Ratio sv(2m): (sv_1+ ...+ sv_32)/(sum_i sv_i)=0.996810
#
# Average dist (m+m_1): 0.719000
# Minmal dist (m+m_1): 0.436253
# Maximal dist (m+m_1): 1.403400
# Average dist (2m): 0.583242
# Minimal dist (2m): 0.067210
# Maximal dist (2m): 0.830713

# %%
mvec = list(range(2,13))
m_x = 4000
m_1 = 1
#UGLY!
ratio_dd_1 = []
ratio_dd_2 = []
ratio_ddd_1 = []
ratio_ddd_2 = []
average_dists_dd_1 = []
average_dists_ddd_1 = []
minimal_dists_dd_1 = []
minimal_dists_ddd_1 = []
maximal_dists_dd_1 = []
maximal_dists_ddd_1 = []
average_dists_dd_2 = []
average_dists_ddd_2 = []
minimal_dists_dd_2 = []
minimal_dists_ddd_2 = []
maximal_dists_dd_2 = []
maximal_dists_ddd_2 = []
#end UGLY
for m in mvec:
    A = ortho_group.rvs(dim = m)
    A = np.transpose(A)
    B = ortho_group.rvs(dim = m)[:m_1]
    B = np.transpose(B)
    X = uniformSphere(m, m_x)
    print("Running for m={},m_1={}, m_x={}:\n".format(m,m_1,m_x))
    print("\n*****************************************************")
    print("\nSVD for unfolding of second derivative:")
    ddf_values, U_dd, D_dd = decomp_svd_dd(X,A,B,randomize=True)
    k = m+m_1

    ratio_sv_1 = np.sum(D_dd[:k])/np.sum(D_dd)
    ratio_dd_1.append(ratio_sv_1)
    ratio_sv_2 = np.sum(D_dd[:2*m])/np.sum(D_dd)
    ratio_dd_2.append(ratio_sv_2)
    dists_1 = []
    dists_2 = []
    for ind in range(m):
        d_1 = np.min(tensor_distance_to_columns(A[:,ind], U_dd, k, mode=2))
        dists_1.append(d_1)
        d_2 = np.min(tensor_distance_to_columns(A[:,ind], U_dd, m*2, mode=2))
        dists_2.append(d_2)
    avg_1 = np.mean(dists_1)
    min_1 = np.min(dists_1)
    max_1 = np.max(dists_1)
    avg_2 = np.mean(dists_2)
    min_2 = np.min(dists_2)
    max_2 = np.max(dists_2)
    average_dists_dd_1.append(avg_1)
    average_dists_dd_2.append(avg_2)
    minimal_dists_dd_1.append(min_1)
    minimal_dists_dd_2.append(min_2)
    maximal_dists_dd_1.append(max_1)
    maximal_dists_dd_2.append(max_2)
    #third derivative
        
    print("\nSVD for unfolding of third derivative:")
    dddf_values, U_ddd, D_ddd = decomp_svd_ddd(X,A,B,randomize=True)
    k = m+m_1
        
    ratio_sv_1 = np.sum(D_ddd[:k])/np.sum(D_ddd)
    ratio_ddd_1.append(ratio_sv_1)
    ratio_sv_2 = np.sum(D_ddd[:2*m])/np.sum(D_ddd)
    ratio_ddd_2.append(ratio_sv_2)
    
    dists_1 = []
    dists_2 = []
    for ind in range(m):
        d_1 = np.min(tensor_distance_to_columns(A[:,ind], U_ddd, k, mode=3))
        dists_1.append(d_1)
        d_2 = np.min(tensor_distance_to_columns(A[:,ind], U_ddd, m*2, mode=3))
        dists_2.append(d_2)
    avg_1 = np.mean(dists_1)
    min_1 = np.min(dists_1)
    max_1 = np.max(dists_1)
    avg_2 = np.mean(dists_2)
    min_2 = np.min(dists_2)
    max_2 = np.max(dists_2)
    #average_dists_dd[i,j]=avg
    average_dists_ddd_1.append(avg_1)
    average_dists_ddd_2.append(avg_2)
    minimal_dists_ddd_1.append(min_1)
    minimal_dists_ddd_2.append(min_2)
    maximal_dists_ddd_1.append(max_1)
    maximal_dists_ddd_2.append(max_2)

    #avg = np.mean(dists)
    #average_dists_ddd[i,j]=avg
# Out:
# Running for m=2,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=3,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=4,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=5,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=6,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=7,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=8,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=9,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=10,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=11,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=12,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:

# %%
ratio_dd_2
# Out:
# [1.0,
#  1.0,
#  0.99999506394669313,
#  0.99998135386366183,
#  0.99990704961075549,
#  0.99991749862007895,
#  0.99975678224549447,
#  0.99986293837834461,
#  0.99958108226845477,
#  0.99986217644031694,
#  0.99973071355950816]

# %%
myplots.plot_summary_dist(mvec, minimal_dists_dd_1,r'Minimal distance', average_dists_dd_1,r'Average distance' ,maximal_dists_dd_1, r'Maximal distance', r'$d(a_i^{\otimes 2}, U_2, m+m_1)$', g_name+"_dd_dist_1.pdf")

# %%
myplots.plot_summary_dist(mvec, minimal_dists_dd_2,r'Minimal distance', average_dists_dd_2,r'Average distance' ,maximal_dists_dd_2, r'Maximal distance', r'$d(a_i^{\otimes 2}, U_2, 2m)$', g_name+"_dd_dist_2.pdf")

# %%
myplots.plot_summary_dist(mvec, minimal_dists_ddd_1,r'Minimal distance', average_dists_ddd_1,r'Average distance' ,maximal_dists_ddd_1, r'Maximal distance', r'$d(a_i^{\otimes 3}, U_3, m+m_1)$', g_name+"_ddd_dist_1.pdf")

# %%
myplots.plot_summary_dist(mvec, minimal_dists_ddd_2,r'Minimal distance', average_dists_ddd_2,r'Average distance' ,maximal_dists_ddd_2, r'Maximal distance', r'$d(a_i^{\otimes 3}, U_3, 2m)$', g_name+"_ddd_dist_2.pdf")

# %%
myplots.plot_summary_ratio(mvec, ratio_dd_1,r'$m+m_1$', ratio_dd_2,r'$2m$', r'Ratio singular values $M_2$', g_name+"_dd_ratio.pdf")

# %%
myplots.plot_summary_ratio(mvec, ratio_ddd_1,r'$m+m_1$', ratio_ddd_2,r'$2m$', r'Ratio singular values $M_3$', g_name+"_ddd_ratio.pdf")
