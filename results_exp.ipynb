# %%
# %matplotlib inline
#Standard imports
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ortho_group


#own modules
import myplots
from tensor_util import *
from main_function import f, df, ddf, dddf

g_name = "exp"
def g(x):
    return np.exp(x)
dg=ddg=dddg=g
# Out:
# [myplots.py]: Saving plots to /home/pca/code/ma/plots

# %%
def uniformSphere(d, m_x):
    x = np.random.normal(size=(m_x,d))
    for i in range(m_x):
        x[i] = x[i] / np.linalg.norm(x[i])
    return x

def perm_matrix(m):
    P = np.identity(m)
    P = np.random.permutation(P)#permutes only the rows
    return P, np.linalg.inv(P)
def decomp_svd_dd(X,A,B, randomize=False):
    """tbd.

    Parameters
    ----------
    X : matrix
        m_x samples \in R^m
    A : matrix
        m orthonormal vectors \in R^m
    B : matrix
        m_1 orthonormal vectors \in R^m
    randomize: bool
        if true performs a random unfolding
    Returns
    -------
    alot

    """
    m = A.shape[1]
    ddf_values = ddf(X,A,B)
    unfolds = [np.reshape(dd, (m**2,)) for dd in ddf_values]
    
    if randomize:
        P,Q = perm_matrix(m**2)
        unfolds = [np.dot(P,v) for v in unfolds]
        
    M = np.transpose(np.array(unfolds))
    U,D,V = np.linalg.svd(M)
    if randomize: 
        U = np.dot(Q,U)
    return ddf_values, U, D
        
    
def decomp_svd_ddd(X,A,B, randomize=False):
    """tbd.

    Parameters
    ----------
    X : matrix
        m_x samples \in R^m
    A : matrix
        m orthonormal vectors \in R^m
    B : matrix
        m_1 orthonormal vectors \in R^m
    randomize: bool
        if true performs a random unfolding
    Returns
    -------
    alot

    """
    m = A.shape[1]
    dddf_values = dddf(X,A,B)
    unfolds = [np.reshape(dd, (m**3,)) for dd in dddf_values]
    
    if randomize:
        P,Q = perm_matrix(m**3)
        unfolds = [np.dot(P,v) for v in unfolds]
        
    M = np.transpose(np.array(unfolds))
    U,D,V = np.linalg.svd(M)
    if randomize: 
        U = np.dot(Q,U)
    return dddf_values, U, D

# %%
#Setting parameters, and creating data
m = 2
m_1 = 1
m_x = 200
X = uniformSphere(m, m_x)
A = ortho_group.rvs(dim = m)# m orthogonal vectors with dim m, a_1, ..., a_m
A = np.transpose(A)
B = ortho_group.rvs(dim = m)[:m_1]#m_1 orthogonal vectors with dimension m b_1, ..., b_m_1
B = np.transpose(B)

# %%
ddf_values, U_dd, D_dd = decomp_svd_dd(X,A,B,randomize=True)
myplots.plot_singular_values(D_dd, m, m_1, m_x, der = 2, filename= g_name + "2nd_2.pdf")
k = m+m_1

print("SVD for unfolding of second derivative:")
ratio_sv_1 = np.sum(D_dd[:k])/np.sum(D_dd)
ratio_sv_2 = np.sum(D_dd[:2*m])/np.sum(D_dd)
print("Ratio singular values: (sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}".format(k, ratio_sv_1))
print("Ratio singular values: (sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}".format(2*m, ratio_sv_2))

print("\nMinimal distance of a_i*a_i to the first m+m_1 left singular vectors:")
for i in range(m):
    print("dist(U[:, :{}], a_{}*a_{}) = {:.6f}".format(k,i,i,np.min(tensor_distance_to_columns(A[:,i], U_dd, k, mode=2))))
print("\nMinimal distance of a_i*a_i to the first 2m left singular vectors:")
for i in range(m):
    print("dist(U[:, :{}], a_{}*a_{}) = {:.6f}".format(2*m,i,i,np.min(tensor_distance_to_columns(A[:,i], U_dd, 2*m, mode=2))))
# Out:
# SVD for unfolding of second derivative:
# Ratio singular values: (sv_1+ ...+ sv_3)/(sum_i sv_i)=1.000000
# Ratio singular values: (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Minimal distance of a_i*a_i to the first m+m_1 left singular vectors:
# dist(U[:, :3], a_0*a_0) = 0.522630
# dist(U[:, :3], a_1*a_1) = 0.367007
#
# Minimal distance of a_i*a_i to the first 2m left singular vectors:
# dist(U[:, :4], a_0*a_0) = 0.522630
# dist(U[:, :4], a_1*a_1) = 0.367007

# %%
dddf_values, U_ddd, D_ddd = decomp_svd_ddd(X,A,B, randomize=False)
myplots.plot_singular_values(D_ddd, m,m_1,m_x, der = 3, filename=g_name + "3rd_2.pdf")
k = m+m_1

print("\nSVD for unfolding of third derivative:")
ratio_sv_1 = np.sum(D_ddd[:k])/np.sum(D_ddd)
ratio_sv_2 = np.sum(D_ddd[:2*m])/np.sum(D_ddd)

print("Ratio singular values:(sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}".format(k, ratio_sv_1))
print("Ratio singular values:(sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}".format(2*m, ratio_sv_2))
print("\nMinimal distance of a_i*a_i*a_i to the first m+m_1 left singular vectors:")
for i in range(m):
    print("dist(U[:, :{}], a_{}*a_{}*a_{}) = {:.6f}".format(k,i,i,i,np.min(tensor_distance_to_columns(A[:,i], U_ddd, k, mode=3))))
print("\nMinimal distance of a_i*a_i*a_i to the first 2m left singular vectors:")
for i in range(m):
    print("dist(U[:, :{}], a_{}*a_{}*a_{}) = {:.6f}".format(2*m,i,i,i,np.min(tensor_distance_to_columns(A[:,i], U_ddd, 2*m, mode=3))))
# Out:
# SVD for unfolding of third derivative:
# Ratio singular values:(sv_1+ ...+ sv_3)/(sum_i sv_i)=0.989456
# Ratio singular values:(sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Minimal distance of a_i*a_i*a_i to the first m+m_1 left singular vectors:
# dist(U[:, :3], a_0*a_0*a_0) = 0.950762
# dist(U[:, :3], a_1*a_1*a_1) = 0.368869
#
# Minimal distance of a_i*a_i*a_i to the first 2m left singular vectors:
# dist(U[:, :4], a_0*a_0*a_0) = 0.653292
# dist(U[:, :4], a_1*a_1*a_1) = 0.368869

# %%
m = [2**k for k in range(1,6)]
m_x = [8**k for k in range(1, 5)]
m_1 = 1
ratio_dd = np.zeros((5,4))
ratio_ddd = np.zeros((5,4))
average_dists_dd = np.zeros((5,4))
average_dists_ddd = np.zeros((5,4))

for i in range(5):
    A = ortho_group.rvs(dim = m[i])
    A = np.transpose(A)
    B = ortho_group.rvs(dim = m[i])[:m_1]
    B = np.transpose(B)
    for j in range(i, 4):
        print("\n*****************************************************")
        print("Running for m={},m_1={}, m_x={}:\n".format(m[i],m_1,m_x[j]))
        X = uniformSphere(m[i], m_x[j])
        print("\nSVD for unfolding of second derivative:")
        ddf_values, U_dd, D_dd = decomp_svd_dd(X,A,B,randomize=True)
        k = m[i]+m_1

        ratio_sv_1 = np.sum(D_dd[:k])/np.sum(D_dd)
        ratio_sv_2 = np.sum(D_dd[:2*m[i]])/np.sum(D_dd)
        #ratio_dd[i,j] = ratio_sv
        print("Ratio sv(m+m_1): (sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}\n".format(k, ratio_sv_1))
        print("Ratio sv(2m): (sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}\n".format(2*m[i], ratio_sv_2))
        
        dists_1 = []
        dists_2 = []
        for ind in range(m[i]):
            d_1 = np.min(tensor_distance_to_columns(A[:,ind], U_dd, k, mode=2))
            dists_1.append(d_1)
            d_2 = np.min(tensor_distance_to_columns(A[:,ind], U_dd, m[i]*2, mode=2))
            dists_2.append(d_2)
        avg_1 = np.mean(dists_1)
        min_1 = np.min(dists_1)
        max_1 = np.max(dists_1)
        avg_2 = np.mean(dists_2)
        min_2 = np.min(dists_2)
        max_2 = np.max(dists_2)
        #average_dists_dd[i,j]=avg
        print("Average dist (m+m_1): {:.6f}".format(avg_1))
        print("Minmal dist (m+m_1): {:.6f}".format(min_1))
        print("Maximal dist (m+m_1): {:.6f}".format(max_1))
        print("Average dist (2m): {:.6f}".format(avg_2))
        print("Minimal dist (2m): {:.6f}".format(min_2))
        print("Maximal dist (2m): {:.6f}".format(max_2))        
        #third derivative
        
        print("\nSVD for unfolding of third derivative:")
        dddf_values, U_ddd, D_ddd = decomp_svd_ddd(X,A,B,randomize=True)
        k = m[i]+m_1
        
        ratio_sv_1 = np.sum(D_ddd[:k])/np.sum(D_ddd)
        ratio_sv_2 = np.sum(D_ddd[:2*m[i]])/np.sum(D_ddd)
        #ratio_ddd[i,j] = ratio_sv
        print("Ratio sv(m+m_1): (sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}\n".format(k, ratio_sv_1))
        print("Ratio sv(2m): (sv_1+ ...+ sv_{})/(sum_i sv_i)={:.6f}\n".format(2*m[i], ratio_sv_2))
        
        dists_1 = []
        dists_2 = []
        for ind in range(m[i]):
            d_1 = np.min(tensor_distance_to_columns(A[:,ind], U_ddd, k, mode=3))
            dists_1.append(d_1)
            d_2 = np.min(tensor_distance_to_columns(A[:,ind], U_ddd, m[i]*2, mode=3))
            dists_2.append(d_2)
        avg_1 = np.mean(dists_1)
        min_1 = np.min(dists_1)
        max_1 = np.max(dists_1)
        avg_2 = np.mean(dists_2)
        min_2 = np.min(dists_2)
        max_2 = np.max(dists_2)
        #average_dists_dd[i,j]=avg
        print("Average dist (m+m_1): {:.6f}".format(avg_1))
        print("Minmal dist (m+m_1): {:.6f}".format(min_1))
        print("Maximal dist (m+m_1): {:.6f}".format(max_1))
        print("Average dist (2m): {:.6f}".format(avg_2))
        print("Minimal dist (2m): {:.6f}".format(min_2))
        print("Maximal dist (2m): {:.6f}".format(max_2))    
            

        #avg = np.mean(dists)
        #average_dists_ddd[i,j]=avg
# Out:
# *****************************************************
# Running for m=2,m_1=1, m_x=8:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=1.000000
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.433938
# Minmal dist (m+m_1): 0.320284
# Maximal dist (m+m_1): 0.547591
# Average dist (2m): 0.433938
# Minimal dist (2m): 0.320284
# Maximal dist (2m): 0.547591
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=0.956417
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.897365
# Minmal dist (m+m_1): 0.504391
# Maximal dist (m+m_1): 1.290340
# Average dist (2m): 0.338626
# Minimal dist (2m): 0.172861
# Maximal dist (2m): 0.504391
#
# *****************************************************
# Running for m=2,m_1=1, m_x=64:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=1.000000
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.317156
# Minmal dist (m+m_1): 0.099328
# Maximal dist (m+m_1): 0.534984
# Average dist (2m): 0.317156
# Minimal dist (2m): 0.099328
# Maximal dist (2m): 0.534984
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=0.927035
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.801294
# Minmal dist (m+m_1): 0.261335
# Maximal dist (m+m_1): 1.341254
# Average dist (2m): 0.188569
# Minimal dist (2m): 0.115804
# Maximal dist (2m): 0.261335
#
# *****************************************************
# Running for m=2,m_1=1, m_x=512:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=1.000000
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.350123
# Minmal dist (m+m_1): 0.129270
# Maximal dist (m+m_1): 0.570977
# Average dist (2m): 0.350123
# Minimal dist (2m): 0.129270
# Maximal dist (2m): 0.570977
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=0.924960
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.760941
# Minmal dist (m+m_1): 0.253763
# Maximal dist (m+m_1): 1.268119
# Average dist (2m): 0.250630
# Minimal dist (2m): 0.247497
# Maximal dist (2m): 0.253763
#
# *****************************************************
# Running for m=2,m_1=1, m_x=4096:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=1.000000
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.337765
# Minmal dist (m+m_1): 0.112518
# Maximal dist (m+m_1): 0.563012
# Average dist (2m): 0.337765
# Minimal dist (2m): 0.112518
# Maximal dist (2m): 0.563012
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_3)/(sum_i sv_i)=0.929852
#
# Ratio sv(2m): (sv_1+ ...+ sv_4)/(sum_i sv_i)=1.000000
#
# Average dist (m+m_1): 0.767206
# Minmal dist (m+m_1): 0.249869
# Maximal dist (m+m_1): 1.284542
# Average dist (2m): 0.248616
# Minimal dist (2m): 0.247362
# Maximal dist (2m): 0.249869
#
# *****************************************************
# Running for m=4,m_1=1, m_x=64:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_5)/(sum_i sv_i)=0.980391
#
# Ratio sv(2m): (sv_1+ ...+ sv_8)/(sum_i sv_i)=0.995557
#
# Average dist (m+m_1): 0.791362
# Minmal dist (m+m_1): 0.235506
# Maximal dist (m+m_1): 1.103322
# Average dist (2m): 0.729868
# Minimal dist (2m): 0.235506
# Maximal dist (2m): 1.004730
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_5)/(sum_i sv_i)=0.981347
#
# Ratio sv(2m): (sv_1+ ...+ sv_8)/(sum_i sv_i)=0.991685
#
# Average dist (m+m_1): 0.943916
# Minmal dist (m+m_1): 0.225206
# Maximal dist (m+m_1): 1.378346
# Average dist (2m): 0.859082
# Minimal dist (2m): 0.225206
# Maximal dist (2m): 1.253358
#
# *****************************************************
# Running for m=4,m_1=1, m_x=512:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_5)/(sum_i sv_i)=0.976253
#
# Ratio sv(2m): (sv_1+ ...+ sv_8)/(sum_i sv_i)=0.993660
#
# Average dist (m+m_1): 0.847283
# Minmal dist (m+m_1): 0.265185
# Maximal dist (m+m_1): 1.186478
# Average dist (2m): 0.739885
# Minimal dist (2m): 0.265185
# Maximal dist (2m): 1.008954
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_5)/(sum_i sv_i)=0.975251
#
# Ratio sv(2m): (sv_1+ ...+ sv_8)/(sum_i sv_i)=0.987602
#
# Average dist (m+m_1): 0.931713
# Minmal dist (m+m_1): 0.251755
# Maximal dist (m+m_1): 1.371009
# Average dist (2m): 0.811350
# Minimal dist (2m): 0.251755
# Maximal dist (2m): 1.167955
#
# *****************************************************
# Running for m=4,m_1=1, m_x=4096:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_5)/(sum_i sv_i)=0.979030
#
# Ratio sv(2m): (sv_1+ ...+ sv_8)/(sum_i sv_i)=0.994511
#
# Average dist (m+m_1): 0.849599
# Minmal dist (m+m_1): 0.244217
# Maximal dist (m+m_1): 1.190489
# Average dist (2m): 0.723911
# Minimal dist (2m): 0.244217
# Maximal dist (2m): 0.945798
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_5)/(sum_i sv_i)=0.978587
#
# Ratio sv(2m): (sv_1+ ...+ sv_8)/(sum_i sv_i)=0.989176
#
# Average dist (m+m_1): 0.922144
# Minmal dist (m+m_1): 0.234292
# Maximal dist (m+m_1): 1.372757
# Average dist (2m): 0.801325
# Minimal dist (2m): 0.234292
# Maximal dist (2m): 1.166024
#
# *****************************************************
# Running for m=8,m_1=1, m_x=512:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_9)/(sum_i sv_i)=0.926900
#
# Ratio sv(2m): (sv_1+ ...+ sv_16)/(sum_i sv_i)=0.980875
#
# Average dist (m+m_1): 1.008709
# Minmal dist (m+m_1): 0.861980
# Maximal dist (m+m_1): 1.287563
# Average dist (2m): 0.976736
# Minimal dist (2m): 0.861270
# Maximal dist (2m): 1.093118
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_9)/(sum_i sv_i)=0.861979
#
# Ratio sv(2m): (sv_1+ ...+ sv_16)/(sum_i sv_i)=0.934261
#
# Average dist (m+m_1): 1.072665
# Minmal dist (m+m_1): 0.836448
# Maximal dist (m+m_1): 1.345309
# Average dist (2m): 1.014780
# Minimal dist (2m): 0.836448
# Maximal dist (2m): 1.223239
#
# *****************************************************
# Running for m=8,m_1=1, m_x=4096:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_9)/(sum_i sv_i)=0.925311
#
# Ratio sv(2m): (sv_1+ ...+ sv_16)/(sum_i sv_i)=0.980296
#
# Average dist (m+m_1): 1.000705
# Minmal dist (m+m_1): 0.848934
# Maximal dist (m+m_1): 1.316340
# Average dist (2m): 0.957851
# Minimal dist (2m): 0.848934
# Maximal dist (2m): 1.088068
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_9)/(sum_i sv_i)=0.858272
#
# Ratio sv(2m): (sv_1+ ...+ sv_16)/(sum_i sv_i)=0.931616
#
# Average dist (m+m_1): 1.082793
# Minmal dist (m+m_1): 0.835049
# Maximal dist (m+m_1): 1.361226
# Average dist (2m): 1.013351
# Minimal dist (2m): 0.835049
# Maximal dist (2m): 1.191195
#
# *****************************************************
# Running for m=16,m_1=1, m_x=4096:
#
#
# SVD for unfolding of second derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_17)/(sum_i sv_i)=0.861169
#
# Ratio sv(2m): (sv_1+ ...+ sv_32)/(sum_i sv_i)=0.913010
#
# Average dist (m+m_1): 1.100813
# Minmal dist (m+m_1): 0.762245
# Maximal dist (m+m_1): 1.390932
# Average dist (2m): 1.046538
# Minimal dist (2m): 0.762245
# Maximal dist (2m): 1.219948
#
# SVD for unfolding of third derivative:
# Ratio sv(m+m_1): (sv_1+ ...+ sv_17)/(sum_i sv_i)=0.785863
#
# Ratio sv(2m): (sv_1+ ...+ sv_32)/(sum_i sv_i)=0.845093
#
# Average dist (m+m_1): 1.166397
# Minmal dist (m+m_1): 0.874808
# Maximal dist (m+m_1): 1.397880
# Average dist (2m): 1.114359
# Minimal dist (2m): 0.874808
# Maximal dist (2m): 1.331067

# %%
mvec = list(range(2,13))
m_x = 4000
m_1 = 1
#UGLY!
ratio_dd_1 = []
ratio_dd_2 = []
ratio_ddd_1 = []
ratio_ddd_2 = []
average_dists_dd_1 = []
average_dists_ddd_1 = []
minimal_dists_dd_1 = []
minimal_dists_ddd_1 = []
maximal_dists_dd_1 = []
maximal_dists_ddd_1 = []
average_dists_dd_2 = []
average_dists_ddd_2 = []
minimal_dists_dd_2 = []
minimal_dists_ddd_2 = []
maximal_dists_dd_2 = []
maximal_dists_ddd_2 = []
#end UGLY
for m in mvec:
    A = ortho_group.rvs(dim = m)
    A = np.transpose(A)
    B = ortho_group.rvs(dim = m)[:m_1]
    B = np.transpose(B)
    X = uniformSphere(m, m_x)
    print("Running for m={},m_1={}, m_x={}:\n".format(m,m_1,m_x))
    print("\n*****************************************************")
    print("\nSVD for unfolding of second derivative:")
    ddf_values, U_dd, D_dd = decomp_svd_dd(X,A,B,randomize=True)
    k = m+m_1

    ratio_sv_1 = np.sum(D_dd[:k])/np.sum(D_dd)
    ratio_dd_1.append(ratio_sv_1)
    ratio_sv_2 = np.sum(D_dd[:2*m])/np.sum(D_dd)
    ratio_dd_2.append(ratio_sv_2)
    dists_1 = []
    dists_2 = []
    for ind in range(m):
        d_1 = np.min(tensor_distance_to_columns(A[:,ind], U_dd, k, mode=2))
        dists_1.append(d_1)
        d_2 = np.min(tensor_distance_to_columns(A[:,ind], U_dd, m*2, mode=2))
        dists_2.append(d_2)
    avg_1 = np.mean(dists_1)
    min_1 = np.min(dists_1)
    max_1 = np.max(dists_1)
    avg_2 = np.mean(dists_2)
    min_2 = np.min(dists_2)
    max_2 = np.max(dists_2)
    average_dists_dd_1.append(avg_1)
    average_dists_dd_2.append(avg_2)
    minimal_dists_dd_1.append(min_1)
    minimal_dists_dd_2.append(min_2)
    maximal_dists_dd_1.append(max_1)
    maximal_dists_dd_2.append(max_2)
    #third derivative
        
    print("\nSVD for unfolding of third derivative:")
    dddf_values, U_ddd, D_ddd = decomp_svd_ddd(X,A,B,randomize=True)
    k = m+m_1
        
    ratio_sv_1 = np.sum(D_ddd[:k])/np.sum(D_ddd)
    ratio_ddd_1.append(ratio_sv_1)
    ratio_sv_2 = np.sum(D_ddd[:2*m])/np.sum(D_ddd)
    ratio_ddd_2.append(ratio_sv_2)
    
    dists_1 = []
    dists_2 = []
    for ind in range(m):
        d_1 = np.min(tensor_distance_to_columns(A[:,ind], U_ddd, k, mode=3))
        dists_1.append(d_1)
        d_2 = np.min(tensor_distance_to_columns(A[:,ind], U_ddd, m*2, mode=3))
        dists_2.append(d_2)
    avg_1 = np.mean(dists_1)
    min_1 = np.min(dists_1)
    max_1 = np.max(dists_1)
    avg_2 = np.mean(dists_2)
    min_2 = np.min(dists_2)
    max_2 = np.max(dists_2)
    #average_dists_dd[i,j]=avg
    average_dists_ddd_1.append(avg_1)
    average_dists_ddd_2.append(avg_2)
    minimal_dists_ddd_1.append(min_1)
    minimal_dists_ddd_2.append(min_2)
    maximal_dists_ddd_1.append(max_1)
    maximal_dists_ddd_2.append(max_2)

    #avg = np.mean(dists)
    #average_dists_ddd[i,j]=avg
# Out:
# Running for m=2,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=3,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=4,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=5,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=6,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=7,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=8,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=9,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=10,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=11,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:
# Running for m=12,m_1=1, m_x=4000:
#
#
# *****************************************************
#
# SVD for unfolding of second derivative:
#
# SVD for unfolding of third derivative:

# %%
some = [np.linalg.norm(np.reshape(x, 12**3)) for x in dddf_values]
some
# Out:
# [1.3909465612437995,
#  1.4575133475306172,
#  1.195135791780634,
#  0.81259240550717859,
#  0.94771636251413793,
#  2.195508881342676,
#  0.72731908085753638,
#  1.8742537343347216,
#  0.61910930267086572,
#  0.88028164797575514,
#  2.8508378158270533,
#  0.81656166023642229,
#  1.7363593847061143,
#  2.0477169112573081,
#  1.3795994543476544,
#  2.18204657373844,
#  0.79202915246469141,
#  1.4175310754392711,
#  2.1036537935128794,
#  1.428736742340355,
#  0.9422656026687064,
#  1.4350320299503083,
#  1.2852241834045375,
#  0.93277669584521894,
#  1.2531094853003391,
#  1.5456556640072587,
#  2.0075122165838475,
#  1.0287130401210267,
#  3.1977792258883198,
#  0.96334461492203283,
#  1.3340065327896664,
#  0.98868142696872308,
#  0.92686610501669664,
#  0.7004090854348991,
#  1.4874939745916524,
#  0.81082263776740748,
#  0.93407540474136952,
#  1.0777508572078254,
#  1.0950657501306706,
#  0.83339936183626206,
#  0.80594182403255421,
#  1.9606263939020332,
#  1.1217215904963995,
#  1.4383677334636089,
#  1.8473161103835414,
#  1.4428780893386437,
#  0.86566074401360815,
#  1.1740648745986932,
#  1.6469887901095548,
#  0.78608599039132299,
#  1.0491333311438613,
#  2.4287765136484096,
#  0.6625530078041717,
#  1.4289275955565726,
#  1.4405433660183937,
#  1.9551364210008328,
#  2.4751107525848894,
#  1.0511574219345912,
#  1.303568913244384,
#  0.75814043274123888,
#  0.99705022564847456,
#  1.0951417005390369,
#  0.72016435069811024,
#  1.4868343453361945,
#  0.89871094357624637,
#  2.0731081568296243,
#  0.92481587495401985,
#  0.78258209916643895,
#  1.1335548850976604,
#  1.3077085359947624,
#  0.77240232956971211,
#  2.6128311489465204,
#  1.2384447536966898,
#  1.8000536325915986,
#  0.85964755098977286,
#  1.8131701006592045,
#  0.76413372202623298,
#  0.90085270690791464,
#  1.0063754904230027,
#  1.0235893173586477,
#  2.2158735313440245,
#  0.82585892771687075,
#  0.76426364747554565,
#  1.060646442249674,
#  0.91116635897830933,
#  1.323082685058701,
#  0.73562610669796502,
#  0.82515879463506303,
#  1.7411082937661104,
#  1.1012784475088671,
#  2.7041023510986468,
#  0.77718200284969674,
#  1.011883675301761,
#  0.937050929280411,
#  1.7787813670689385,
#  1.5434337223357013,
#  1.7473763633996118,
#  1.5278993360937105,
#  0.95657505745081362,
#  0.89391898513732082,
#  1.2429346218933424,
#  1.0532347622204357,
#  0.89231825655050467,
#  0.798570783801692,
#  2.0191427372161082,
#  0.89080892008908519,
#  0.804332084676467,
#  0.71911430544743049,
#  0.71999065032379783,
#  0.9498890843534693,
#  1.5518248780492687,
#  0.74950107081164163,
#  1.0108845441193,
#  1.3531901960091792,
#  1.2661726534786673,
#  1.9297500266347867,
#  0.81696239490887279,
#  1.1358915300196242,
#  0.93838478823013494,
#  2.7265834749522107,
#  0.98309459456209203,
#  0.94064003428288712,
#  1.0449288660073366,
#  1.8865062516716207,
#  1.1205288121464658,
#  2.6137771249317554,
#  0.95521205566406597,
#  1.7438684791340004,
#  1.0450126032819842,
#  1.0112479677385438,
#  0.77203145778812587,
#  1.3700312929554623,
#  1.1845080963137133,
#  1.3302548082429733,
#  1.9588925242549098,
#  0.99975799856502634,
#  1.7641726126192763,
#  0.79834614656143421,
#  1.798661198160052,
#  2.7662780566691705,
#  1.0572233122637897,
#  1.0493556458293412,
#  1.1766059257846637,
#  0.99971552597608482,
#  1.6493326751558748,
#  0.83462358280565174,
#  0.75796356168789059,
#  1.6687777105880586,
#  2.4432704101820857,
#  1.4672009713701673,
#  1.8366869059734769,
#  0.74986478563485726,
#  1.3188239075288792,
#  0.96493479686024208,
#  0.85683331162695497,
#  0.74513323857499225,
#  1.7135369144218731,
#  0.94990515218846616,
#  0.98157766877342889,
#  0.7632273266669356,
#  2.1048480962509553,
#  2.0609849848175377,
#  1.4367990876204628,
#  0.8588878820874789,
#  0.83164785660889262,
#  1.0044312624701521,
#  1.697483486551699,
#  1.6565314148422461,
#  0.80680545787935043,
#  1.1702211723166291,
#  1.1750218691682406,
#  0.94152007041395203,
#  0.6285803039930391,
#  2.7988836779977246,
#  1.1417486692649281,
#  0.66386099451152181,
#  0.65323545020116691,
#  1.3423344926940124,
#  1.4474286716959535,
#  0.69999885460588152,
#  0.78281898940508365,
#  1.1425734384675355,
#  1.2757031255200861,
#  1.3032116456395189,
#  1.4778016822358238,
#  1.3691478586610606,
#  0.92980332989995118,
#  1.2194104427151407,
#  0.95918044509062461,
#  0.83125637825515197,
#  1.2980306925223983,
#  2.4916146998259818,
#  0.50215541696405119,
#  1.8738233480187834,
#  1.0005477459622008,
#  1.233284374143552,
#  1.676032560630289,
#  3.0542270019280675,
#  1.2427263624984031,
#  1.7739378771347742,
#  1.459105042991329,
#  1.4236663715078737,
#  1.6745102813544228,
#  1.0537533992464709,
#  0.63092954013503511,
#  1.1117842849400323,
#  0.59614055703828517,
#  1.1422288955895352,
#  1.6011526611924733,
#  1.7582662849805777,
#  0.77870036115787822,
#  3.2738228000850724,
#  1.1386771054142553,
#  0.78629226743868652,
#  1.0794253305941222,
#  1.45349230473688,
#  1.5250530887534184,
#  1.1874722033855452,
#  1.7556825629793003,
#  1.4106817207002429,
#  0.73667487357854844,
#  2.1491199948016497,
#  0.5697957048832486,
#  1.1146092338290803,
#  0.92259998332278481,
#  1.1569101396597776,
#  0.63170413351101062,
#  1.8989758643692405,
#  1.500703354162058,
#  1.0712708984821584,
#  1.6584429618548033,
#  1.2852072230474654,
#  1.5857011336142033,
#  1.3781432187414429,
#  1.5813992170310824,
#  0.78967149174346618,
#  0.64214043189293979,
#  0.73477360316348628,
#  1.111751585951098,
#  1.2794992899463447,
#  0.69014529477768471,
#  0.59810226553304036,
#  1.0273092298141104,
#  1.3271826407032068,
#  1.8911188406994415,
#  0.9336379911041327,
#  1.3601364231352175,
#  1.4091748600202973,
#  1.7721791102699382,
#  1.3933446266947567,
#  0.78626889914785647,
#  0.94538063631029978,
#  1.4044146250366027,
#  1.3376033712169226,
#  0.62840224805296951,
#  1.0137472418804498,
#  1.2424020356737506,
#  1.2827502224018117,
#  0.49262597729333146,
#  0.92405844302811502,
#  1.0408041299902651,
#  1.0796961870489894,
#  1.2198256126681013,
#  1.1322818013581795,
#  2.2700032894438,
#  1.3847328436943558,
#  1.6262512086623933,
#  0.72938735047771908,
#  1.3787625089550251,
#  0.75099776493017911,
#  1.4209905282737709,
#  0.85097722949037302,
#  1.470383763238633,
#  1.2951404899022092,
#  0.78184599190856996,
#  1.2310596237623495,
#  1.5529212649108033,
#  1.2707771031370514,
#  1.4887960864033458,
#  1.2384987756605721,
#  0.89360515192742662,
#  1.4934649396327779,
#  0.68802539291477605,
#  2.8812043049795748,
#  1.1702882710469322,
#  0.75430445245479072,
#  1.171648264852736,
#  1.0157142489864166,
#  0.95413170701365657,
#  0.87470975159018105,
#  0.73723705371220516,
#  2.8819685370810602,
#  1.6305833795125435,
#  0.56312105035542737,
#  0.94669106598862063,
#  1.049169965403709,
#  1.502725351359123,
#  0.93194150083272742,
#  1.5134592582202455,
#  3.5310929575414578,
#  1.0012996728169372,
#  0.731214299173649,
#  1.1213661047934422,
#  1.2149673124519764,
#  1.0253285871770634,
#  0.79057067552605342,
#  0.78999695601968101,
#  1.1013874174743552,
#  1.3145877863046733,
#  0.69783629474904529,
#  1.4345049210971632,
#  0.72000122678284617,
#  0.53284051309408464,
#  1.9328607816964327,
#  1.6695733982281473,
#  0.82239944388414732,
#  3.3043065525014175,
#  1.2800858291573294,
#  0.80325884892770361,
#  0.69185179181846201,
#  1.0268385590734854,
#  2.2350555514933013,
#  0.7009140315077631,
#  1.5382080872952748,
#  2.4218301612412438,
#  0.96879576949342616,
#  0.94361579597004019,
#  1.0644169556447296,
#  0.9305699823243988,
#  1.0026589905200038,
#  2.1167736914091124,
#  0.61408272237370132,
#  1.2085823256383466,
#  0.61929929433450881,
#  1.2733072408224553,
#  0.77229403063313495,
#  0.99242167131843495,
#  0.84758310033692841,
#  1.0109528084057973,
#  1.3215513435025172,
#  1.0269737363798022,
#  1.0109740512558354,
#  1.3819106630838467,
#  3.0805041889350586,
#  1.5051498186500869,
#  1.0620222259474836,
#  2.2357950241737536,
#  0.74038998543019097,
#  1.0291773415767791,
#  0.99921239292138486,
#  1.3141682516901536,
#  0.88101045160152969,
#  1.0692339284513284,
#  0.70913139676100001,
#  2.1626269038572312,
#  1.6341477933005906,
#  1.29515013536599,
#  0.92690487450118975,
#  1.6833289647872558,
#  2.5503180662114113,
#  0.9829668050758259,
#  2.1397791298903681,
#  0.86671188199565508,
#  0.82011845310044662,
#  0.70275078710572803,
#  1.1433040397337522,
#  0.86260766892471352,
#  0.93529446621889334,
#  1.0551064621771022,
#  1.2614679091623708,
#  1.1546058481070831,
#  1.0417702086428557,
#  1.2823792261690841,
#  1.095398687082882,
#  1.5973570896871032,
#  1.5046294997322003,
#  2.0063230409251975,
#  2.1764688922870938,
#  1.4762560704974204,
#  1.3898649931178058,
#  1.1838428979593145,
#  1.4902783142904812,
#  2.3397857903612476,
#  2.0937571408163933,
#  1.2121988803827477,
#  2.980956918840306,
#  0.78722241289869765,
#  1.306396692200938,
#  1.2145521206988794,
#  1.4551493671532447,
#  1.1206746094947821,
#  1.3600624560562364,
#  1.1854033241595505,
#  1.8699661258741882,
#  0.86869262147749671,
#  1.7460007372139803,
#  1.1484602160436788,
#  1.3022039675784423,
#  0.5630965432321553,
#  0.80232307265231428,
#  0.88056924818867333,
#  3.4557559085843383,
#  0.83142551421829169,
#  0.84462597291365937,
#  1.241839276438518,
#  2.7691857403687572,
#  0.62313678216724833,
#  1.5513431628366967,
#  1.4803862909550942,
#  1.5193033724741576,
#  1.5799040938390323,
#  1.4856122678256138,
#  1.1370307677047118,
#  1.837449560959352,
#  1.7106579662869401,
#  1.4629874411181583,
#  0.7725087851947684,
#  2.168474079938711,
#  1.370638006657118,
#  2.675303400661067,
#  1.3580022480269134,
#  1.616264044401404,
#  1.1121656388032077,
#  1.6507004842772441,
#  0.77529884014679296,
#  1.4238562712354668,
#  0.92948723783240184,
#  1.527430589134199,
#  1.1926824311106052,
#  1.2142607196107449,
#  1.0296496015925751,
#  0.84310144430378997,
#  1.1737373021404658,
#  1.7184676996604566,
#  0.88387154463385176,
#  0.6197020706949693,
#  2.0294791997866377,
#  1.1552459251049907,
#  1.9309779890134295,
#  0.90761556797715781,
#  1.5315615381944305,
#  1.2864183117763088,
#  0.96738682237471652,
#  1.5752757835350131,
#  1.1795339507395435,
#  0.70011001679583507,
#  3.3990429344334743,
#  1.1437406159326655,
#  1.7679876772741625,
#  3.197863457798757,
#  1.4537000698770883,
#  1.7501361514444764,
#  1.090195249669335,
#  0.77255318199773293,
#  1.0228023782165199,
#  1.9344826535650461,
#  1.423742484009489,
#  3.0557012903002341,
#  1.500445278945068,
#  1.1099335162087638,
#  1.2872188677299596,
#  1.9752225924095308,
#  0.79668380586514465,
#  1.3465444328133331,
#  1.57061105962702,
#  1.5030065252496387,
#  0.97250000433744854,
#  1.0039966833066811,
#  1.9518261107607975,
#  0.84892539900167197,
#  0.95498238109100353,
#  1.1513685246917771,
#  1.6819382480247522,
#  0.91589373414988062,
#  0.77101600998000031,
#  2.2447205102665286,
#  1.2780256968011099,
#  2.6982796251858829,
#  1.3836144274856665,
#  1.4290219507246569,
#  1.1209276679379352,
#  0.59338412967710952,
#  1.1766695146479262,
#  1.4881792217069498,
#  1.6199857130075535,
#  0.85322120920762112,
#  0.67159310883964485,
#  1.8602444758059986,
#  1.0691510136946589,
#  1.9704076965645121,
#  1.0299004839526134,
#  1.0342491788050889,
#  1.0150395811337269,
#  0.68490388234825816,
#  0.76322026179471059,
#  0.75258522421024543,
#  1.151807192002555,
#  0.56746231376125189,
#  2.0618943499565177,
#  1.1052246807072672,
#  1.0213740875989685,
#  1.0052394039232495,
#  0.80549191212517601,
#  0.73287198787768337,
#  0.92690240504557408,
#  1.5750849713099544,
#  0.91776709331552564,
#  1.2855837186806534,
#  2.335828516700361,
#  1.6308459650108909,
#  1.4497835320740275,
#  1.0662703177623223,
#  0.78469617334283415,
#  1.3849741221357137,
#  1.0120818910760485,
#  0.69435631497847006,
#  2.1672925346358065,
#  1.1964938764705633,
#  1.3096882065498592,
#  0.76924530348969522,
#  0.81194499453664626,
#  0.84963829359359111,
#  1.1449022521754206,
#  1.4512675612211865,
#  2.0721969638889175,
#  1.1874247522903023,
#  1.7216073036641215,
#  0.78550862383680631,
#  1.1034286931424644,
#  0.8254036380427745,
#  0.62051294699972737,
#  0.98386457046570075,
#  1.919380894333254,
#  0.70852932960247039,
#  1.0845959111078631,
#  1.1660685191535576,
#  0.652311850316735,
#  1.6754296321409434,
#  0.85669738051779987,
#  1.8659933087253566,
#  1.034840344781387,
#  0.96878910759614445,
#  0.96195009420917432,
#  2.3900724979493453,
#  1.1840592985569545,
#  1.5877393741427399,
#  1.3247278715758029,
#  2.049068422817673,
#  1.4463249030501661,
#  1.0982479290524563,
#  0.75059029476446693,
#  0.88238109746592908,
#  1.0607828925016114,
#  1.3974170008054381,
#  1.7638033020857049,
#  1.8736736830976493,
#  0.7921513114138935,
#  1.5062231412471589,
#  1.1782194272477156,
#  2.0505198356880117,
#  1.7173718953625103,
#  0.92600779043440185,
#  1.3760676168038697,
#  1.1314401043643314,
#  1.3171158955655113,
#  1.3155040302894574,
#  0.71718899442664774,
#  2.4954423457160066,
#  0.87031871478672007,
#  2.0700917908330605,
#  0.85702495732272588,
#  2.1993716771142084,
#  0.78164071725277173,
#  1.0515563778591148,
#  0.71990002894453287,
#  0.98154667710203725,
#  0.9311742909099967,
#  1.2366020193864258,
#  1.4630103228722264,
#  2.9717004191071603,
#  0.58162029385492164,
#  1.1052861327759644,
#  2.0412625967242248,
#  1.8405303411536631,
#  1.2073007568060174,
#  0.54958565873575194,
#  0.74089885253708421,
#  1.3121207451913726,
#  1.6822392217934528,
#  0.82615053753977286,
#  0.69326677847323437,
#  0.7219887649481237,
#  1.8985225439891951,
#  1.4609917097181553,
#  0.92361786016328162,
#  1.1596751417250271,
#  1.5963182963937623,
#  0.79508071617779597,
#  0.89501295702702988,
#  1.1521649746582048,
#  0.83292274542538469,
#  1.3475977744841665,
#  0.89573745939974125,
#  0.71043976205540094,
#  1.3119279554712837,
#  1.978900762849666,
#  1.9290411241221632,
#  0.85586196536586967,
#  1.4674452042346777,
#  0.95246475484268123,
#  3.0636163212834107,
#  1.4455402262055344,
#  3.4614767888086764,
#  1.0656553048275317,
#  1.24889448235676,
#  0.8296315728066348,
#  1.7391907086101603,
#  0.93248897597571168,
#  1.109149261349712,
#  1.2373043525766689,
#  1.3543827941545312,
#  0.93522673066954609,
#  1.8391507719641766,
#  2.2195088723930247,
#  2.6636395132047785,
#  1.3365593092943739,
#  1.3212542147270696,
#  1.4851149789203719,
#  0.76403261735856376,
#  0.94164774660398254,
#  0.99693096375533674,
#  1.7499031504567724,
#  1.0705678261364953,
#  1.0862249109131632,
#  1.5703721862171505,
#  1.2744917009749164,
#  1.528481876389794,
#  0.76746558528269704,
#  2.2515949822365182,
#  0.69285489001464418,
#  1.1996728557490353,
#  2.67642742597954,
#  0.97787578829697941,
#  0.69686800520544745,
#  0.81859635924773388,
#  0.62917692668550873,
#  1.3153782060075405,
#  1.1928065607015164,
#  3.1797183924836387,
#  0.74414292502214363,
#  2.0236932829312515,
#  1.0505648602530502,
#  2.8633894308538634,
#  0.70632080678876674,
#  1.756233678242926,
#  0.83497933807044122,
#  2.5123000431143012,
#  2.197738598785171,
#  1.853126699809948,
#  1.458987303600414,
#  1.1772753738803876,
#  1.8750621425470249,
#  2.1923667868294334,
#  1.0503950282089016,
#  0.77832033277285551,
#  1.2836715535834675,
#  2.1701251686814911,
#  1.17493412714307,
#  1.3659582659706431,
#  2.1747577226789256,
#  1.4213522932537315,
#  0.89331911334466674,
#  1.6993227018384971,
#  0.58143757175547639,
#  0.70823097435473792,
#  1.1437525606823715,
#  3.0564545594169128,
#  1.6566374549576097,
#  1.1504001296556328,
#  0.87704310949914643,
#  2.0844794913065114,
#  2.5106037098323002,
#  1.2783480790812713,
#  0.99162959673657824,
#  1.553014571205769,
#  0.72141481288085796,
#  2.1404273770949831,
#  1.221745420374285,
#  1.8137052265827212,
#  2.4531261154304702,
#  1.5113006532813136,
#  1.3173095878160659,
#  0.96995255819583126,
#  0.84773334258266575,
#  0.81492826381984196,
#  0.99668822334235141,
#  1.0295263582257823,
#  0.94666933154643251,
#  1.0047027226379122,
#  0.85746603092355667,
#  1.0287575271988236,
#  0.71259810090002951,
#  1.0421424024027621,
#  0.77391762269630893,
#  0.78859020910544431,
#  1.1128525784594225,
#  1.5539779577510324,
#  1.0629902154704112,
#  1.3495824336536535,
#  1.0240453056663048,
#  1.0969666771571094,
#  1.1816466216639347,
#  0.72215721247695308,
#  1.2183932596165867,
#  0.97037417645473345,
#  3.0743302109689448,
#  0.95534363141864742,
#  0.97756997922190991,
#  1.0997775448226623,
#  0.72042767836087829,
#  1.5798547179375371,
#  1.1488879756263464,
#  1.6654674193896861,
#  1.386453222805401,
#  2.2425408014550126,
#  1.8289325178768907,
#  0.86134108028180456,
#  1.2154520924621717,
#  1.6985381351468103,
#  0.585249858896702,
#  1.1811567506536211,
#  2.9705501535897096,
#  1.2458568784431907,
#  2.5844323279321437,
#  1.0948941793013587,
#  1.707188603932974,
#  1.1998323850329373,
#  1.4609210356750422,
#  1.7245091615072541,
#  0.79130052194412592,
#  1.392427592360022,
#  1.3035155079944738,
#  1.2947695063531048,
#  0.98629575188488205,
#  1.3184178275957048,
#  0.90860900709587644,
#  0.90879573420565307,
#  1.4053538499117824,
#  1.4584799780736415,
#  1.0585101759944804,
#  3.0062931111348852,
#  1.7137111921663601,
#  1.1957937152280487,
#  1.4048102077420588,
#  0.73479269902379829,
#  0.89850428642605717,
#  1.0510135641179124,
#  1.4853507739305445,
#  1.9012533096347239,
#  3.0558731188862862,
#  1.3529670056875858,
#  1.0842600234964921,
#  0.80464487199856027,
#  0.99304208842391106,
#  0.83609712978977757,
#  1.2505063566438603,
#  1.7353693241950316,
#  1.487736863242193,
#  1.3252265513567869,
#  1.5941303724254299,
#  1.2170788470626261,
#  1.3698109404075216,
#  1.6961507745097062,
#  1.1851130759673005,
#  0.87379817093917123,
#  1.5768501753467148,
#  0.90822807829423657,
#  1.4334300921359835,
#  1.8203644495369431,
#  1.2505830637628674,
#  2.2357190453645766,
#  0.59738496665007024,
#  0.79097471285251375,
#  1.7095866638651185,
#  0.97039480018266744,
#  0.93997718788786166,
#  0.65769333335436031,
#  0.92103564850374509,
#  1.9598466554668443,
#  1.3767786665653312,
#  1.6948444330055772,
#  1.3954595360102877,
#  1.3213948022287061,
#  1.4797968809204838,
#  1.3395306306329393,
#  2.6024416475278604,
#  1.4826672929614326,
#  1.3361196730974081,
#  1.4507429283337234,
#  1.5380756752827682,
#  0.79443258266972949,
#  1.7478015039221282,
#  0.90092406524232305,
#  0.86416983335803654,
#  1.0142308538739822,
#  1.054586273014092,
#  0.75749204992222374,
#  0.94262818365571344,
#  0.93344473052706511,
#  1.0692388639801729,
#  0.93087434180034256,
#  1.6446880569366353,
#  0.8044667841659191,
#  3.1726420913218298,
#  0.77920283439639959,
#  2.0086604819478824,
#  1.2720232689366044,
#  0.78753741169128255,
#  1.0502785312916074,
#  1.3577621749745754,
#  0.62793809527197231,
#  1.1140502975189137,
#  0.79497530909766823,
#  1.3763412709959257,
#  0.98401797913238431,
#  2.0279344017668675,
#  1.0460140385454757,
#  1.0616429774443414,
#  1.3706942822704444,
#  1.0434042932849195,
#  2.2046388922579836,
#  1.6744075112784707,
#  1.2838832396111064,
#  0.66325759173057042,
#  0.62243714245522597,
#  1.8151671911711749,
#  0.87903302314810372,
#  0.63933518054413707,
#  1.3291054750582403,
#  1.2607516728824282,
#  0.95596907484338811,
#  1.2506005460519529,
#  1.5734239575428652,
#  1.2250293136442809,
#  0.99704279770473614,
#  1.5053005230928294,
#  1.535948582181845,
#  0.95241267110655303,
#  0.8262737681191975,
#  1.7609188721643476,
#  2.0553195753230007,
#  1.1922236354879996,
#  1.1262105315061046,
#  1.045590183627277,
#  0.80433672914466703,
#  1.6738049840608114,
#  0.88111555719383117,
#  1.2368084152690153,
#  1.2741354031970542,
#  1.1828993744129808,
#  0.6675041162571157,
#  1.9035907854720739,
#  1.6588232874150388,
#  0.77942353230783457,
#  1.8355283573540107,
#  1.3556221616249904,
#  1.3937231042671778,
#  1.0322221427979603,
#  0.70115735300631699,
#  1.0727625510104366,
#  2.2675068563246756,
#  1.1635987328470625,
#  0.73481447594907268,
#  0.58482748327339018,
#  2.7785777858747269,
#  0.84656573495185306,
#  2.6632091927908572,
#  1.7041134688236632,
#  0.892446934420422,
#  1.8532375535240451,
#  0.60813455440276931,
#  1.1508209448832563,
#  1.1079253104612883,
#  1.0806302343619401,
#  1.8608469962503049,
#  0.92961899472498111,
#  1.2660564403905592,
#  1.4793842173543483,
#  1.2879224234735123,
#  0.61002388053489176,
#  1.2661709077397598,
#  1.902403587428793,
#  0.65067490139288209,
#  0.76676355629851412,
#  1.9814401541615507,
#  1.1384434184276289,
#  0.64788522136621196,
#  0.67228251295669839,
#  0.87944092262734697,
#  2.4633340790185003,
#  2.1906113365708948,
#  2.6447001870267162,
#  1.4882492482165002,
#  1.2782570722552713,
#  1.9009223351552369,
#  0.8190818227316109,
#  0.87321268056684564,
#  0.85126610536203728,
#  0.87370636621667541,
#  0.8424344701512011,
#  1.4793661556056747,
#  0.66278803810126041,
#  1.8777356381709329,
#  2.0664206262867544,
#  1.7528400821656152,
#  1.5875909667143444,
#  2.4142714966810579,
#  1.4158579507025479,
#  1.5764297896112855,
#  1.7398911642061679,
#  0.87979420131997577,
#  0.75058632226611743,
#  1.2410525889470858,
#  2.2571584932767399,
#  0.75123448208246824,
#  1.8197583845853071,
#  0.65838205128760252,
#  1.843522656216088,
#  0.83521959061490292,
#  1.5414643382906872,
#  0.69196199854027507,
#  0.85987891780418912,
#  1.8129192197923636,
#  1.0940465786811717,
#  1.5256821902470112,
#  0.86068472436192611,
#  0.85490685266937894,
#  1.7089617258803103,
#  1.0518398333208394,
#  2.270159984823823,
#  1.4003425809674517,
#  0.63185656087860331,
#  1.3838138680000855,
#  0.9958272296171472,
#  0.77637442940063517,
#  1.073717450534293,
#  1.9771388075977581,
#  0.62448715871746763,
#  1.3957482126556569,
#  2.1366161187990338,
#  0.50725302284406626,
#  1.0978391038819564,
#  1.1048367138959194,
#  1.4073561257387168,
#  0.92911326302848896,
#  0.84677709618535246,
#  0.9564013674340035,
#  1.7572324726696547,
#  1.751991700304657,
#  1.9223947691356296,
#  2.4879414005358105,
#  0.8619879191010259,
#  0.83906320225567688,
#  1.1478887031317557,
#  0.67850304748637458,
#  1.1211176017134716,
#  0.96673177459924509,
#  1.072708480922131,
#  1.4156038745998245,
#  0.68603039803223831,
#  0.71119318693298261,
#  0.75190014160284302,
#  1.1485305199772304,
#  0.88699731635917123,
#  0.80659965724629834,
#  1.9942193267871273,
#  0.76449255938630856,
#  0.83219423218525901,
#  1.6188438299634473,
#  1.5098105062697287,
#  0.70592425744370924,
#  1.4301209032879245,
#  1.2960946317014497,
#  1.0445212755560256,
#  1.392074245822182,
#  1.4833599323747368,
#  0.95482390030787123,
#  1.2793009697034694,
#  1.2983358002096537,
#  0.91105730166217302,
#  0.90283487699625919,
#  3.1734159184169122,
#  1.3733486368535197,
#  1.4986867736685023,
#  1.0408922964595413,
#  1.1089862355987057,
#  0.95444777907391898,
#  0.82796444856203177,
#  1.0518576688209371,
#  1.0743014613189219,
#  ...]

# %%
myplots.plot_summary_dist(mvec, minimal_dists_dd_1,r'Minimal distance', average_dists_dd_1,r'Average distance' ,maximal_dists_dd_1, r'Maximal distance', r'$d(a_i^{\otimes 2}, U_2, m+m_1)$', g_name+"_dd_dist_1.pdf")

# %%
myplots.plot_summary_dist(mvec, minimal_dists_dd_2,r'Minimal distance', average_dists_dd_2,r'Average distance' ,maximal_dists_dd_2, r'Maximal distance', r'$d(a_i^{\otimes 2}, U_2, 2m)$', g_name+"_dd_dist_2.pdf")

# %%
myplots.plot_summary_dist(mvec, minimal_dists_ddd_1,r'Minimal distance', average_dists_ddd_1,r'Average distance' ,maximal_dists_ddd_1, r'Maximal distance', r'$d(a_i^{\otimes 3}, U_3, m+m_1)$', g_name+"_ddd_dist_1.pdf")

# %%
myplots.plot_summary_dist(mvec, minimal_dists_ddd_2,r'Minimal distance', average_dists_ddd_2,r'Average distance' ,maximal_dists_ddd_2, r'Maximal distance', r'$d(a_i^{\otimes 3}, U_3, 2m)$', g_name+"_ddd_dist_2.pdf")

# %%
myplots.plot_summary_ratio(mvec, ratio_dd_1,r'$m+m_1$', ratio_dd_2,r'$2m$', r'Ratio singular values $M_2$', g_name+"_dd_ratio.pdf")

# %%
myplots.plot_summary_ratio(mvec, ratio_ddd_1,r'$m+m_1$', ratio_ddd_2,r'$2m$', r'Ratio singular values $M_3$', g_name+"_ddd_ratio.pdf")
